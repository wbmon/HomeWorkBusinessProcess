# %% [markdown]
# **Возьмите для примера две одинаковые компании из одной индустрии**
#
#
# ### Задание 1 .
# **Опишите их главные отличия в бизнес-процессах.**

# %% [markdown]
# ### Решение.
# Так как я уже 30 лет являюсь работником сферы образования, для примера возьму образовательные организации.
# Сравним бизнес-процессы обычной общеобразовательной школы и онлайн-школы английского языка Skillbox.
# Так как в задании требуется указать их главные *отличия*, то представлю их в виде таблицы:
#
# | **_Основные бизнес-процессы в образовании_**     | **_Средняя общеобразовательная школа_** | **_Онлайн-школа английского языка_** |
# |--------------------------------------------------|:---------------------------------------:|:------------------------------------:|
# | Образовательная деятельность                     |                  *                      |                   *                   |
# | Воспитательная деятельность                      |                  *                      |                                       |
# | Научно-исследовательская деятельность            |                  *                      |                                       |
# | Организационно-методическая деятельность         |                  *                      |                   *                   |
# | Социальная деятельность                          |                  *                      |                                       |
# | Укрепление здоровья и охрана жизни ученика       |                  *                      |                                       |
# | Платные образовательные услуги                   |                  *                      |                   *                   |
# | Педагогическая диагностика                       |                  *                      |                                       |
# | Маркетинг                                        |                                         |                   *                   |

# %% [markdown]
# ### Задание 2.
# **Перечислите основные и вспомогательные бизнес-процессы.**

# %% [markdown]
# ### Решение.
#
# <table border="1" cellpadding="50"><tr><th rowspan="9" valign="top"><b>Основные бизнес-процессы</b></th><th valign="top">Образовательная деятельность</th></tr>
# <tr><td valign="top">Воспитательная деятельность</td></tr>
# <tr><td valign="top">Научно-исследовательская деятельность</td></tr>
# <tr><td valign="top">Организационно-методическая деятельность</td></tr>
# <tr><td valign="top">Социальная деятельность</td></tr>
# <tr><td valign="top">Укрепление здоровья и охрана жизни ученика</td></tr>
# <tr><td valign="top">Платные образовательные услуги</td></tr>
# <tr><td valign="top">Педагогическая диагностика</td></tr>
# <tr><td valign="top">Маркетинг</td></tr>
# <tr><td rowspan="4" valign="top"><b>Обеспечивающие бизнес-процессы</b></td><td valign="top">Кадровое обеспечение</td></tr>
# <tr><td valign="top">Методическое обеспечение</td></tr>
# <tr><td valign="top">Финансовое обеспечение</td></tr>
# <tr><td valign="top">Материально-техническое обеспечение </td></tr>
# <tr><td rowspan="4" valign="top"><b>Бизнес-процессы управления</b></td><td valign="top">Управление учителями</td></tr>
# <tr><td valign="top">Управление вспомогательным персоналом</td></tr>
# <tr><td valign="top">Управление финансами</td></tr>
# <tr><td valign="top">Стратегическое управление</td></tr>
# <tr><td rowspan="5" valign="top"><b>Бизнес-процессы развития</b></td><td valign="top">Разработка инновационных технологий обучения</td></tr>
# <tr><td valign="top">Повышение квалификации учителей</td></tr>
# <tr><td valign="top">Развитие финансового обеспечения</td></tr>
# <tr><td valign="top">Развитие связей с учреждениями профобразования</td></tr>
# <tr><td valign="top">Развитие научно-методических и научных контактов</td></tr>
# </table>
